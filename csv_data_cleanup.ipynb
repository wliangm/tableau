# %%
import glob
import pandas as pd
import numpy as np
import csv
from datetime import datetime
from pandas.io.parsers import read_csv

# %%
path2 =r'C:\Users\LENOVO USER\Desktop\USC Data Bootcamp\18-Tableau\Data2'

#store all csv file names into a list through glob (pathname)
allFiles2 = glob.glob(path2 + "/*.csv")

# %%
with open('citi_bike2.csv', 'a') as mergedCSV2:
    for csv_x2 in allFiles2:
        for line in open(csv_x2, 'r'):
            mergedCSV2.write(line)

# %%
merged_file2 = "C:/Users/LENOVO USER/Desktop/USC Data Bootcamp/18-Tableau/citi_bike2.csv"

merged_df2 = pd.read_csv(merged_file2, encoding="ISO-8859-1")

#check
merged_df2.head()
# Out:
# C:\Users\LENOVO USER\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (0,3,5,6,7,9,10,11,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Trip Duration           Start Time            Stop Time Start Station ID  \
# 0            61  2015-09-21 14:53:16  2015-09-21 14:54:17             3185
# 1           290  2015-09-21 14:55:59  2015-09-21 15:00:50             3183
# 2           786  2015-09-21 14:56:14  2015-09-21 15:09:21             3183
# 3           477  2015-09-21 14:58:35  2015-09-21 15:06:32             3203
# 4           451  2015-09-21 14:59:55  2015-09-21 15:07:27             3203
#
#   Start Station Name Start Station Latitude Start Station Longitude  \
# 0          City Hall             40.7177325              -74.043845
# 1     Exchange Place             40.7162469             -74.0334588
# ...
